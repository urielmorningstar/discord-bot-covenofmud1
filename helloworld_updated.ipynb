# %% [markdown]
# <a href="https://colab.research.google.com/github/urielmorningstar/discord-bot-covenofmud1/blob/main/helloworld_updated.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello, world!")
# Out:
# Hello, world!
